# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
train = pd.read_csv("/content/drive/MyDrive/Project Data Mining/Predicting Coupon Redemption/train.csv")
demographics = pd.read_csv("/content/drive/MyDrive/Project Data Mining/Predicting Coupon Redemption/customer_demographics.csv")
transaction = pd.read_csv("/content/drive/MyDrive/Project Data Mining/Predicting Coupon Redemption/customer_transaction_data.csv", parse_dates=['date'])
coupon_item = pd.read_csv("/content/drive/MyDrive/Project Data Mining/Predicting Coupon Redemption/coupon_item_mapping.csv")
item = pd.read_csv("/content/drive/MyDrive/Project Data Mining/Predicting Coupon Redemption/item_data.csv")
campaign = pd.read_csv("/content/drive/MyDrive/Project Data Mining/Predicting Coupon Redemption/campaign_data.csv", parse_dates=['start_date','end_date'])

# %%
train.head()
# Out:
#    id  campaign_id  coupon_id  customer_id  redemption_status
# 0   1           13         27         1053                  0
# 1   2           13        116           48                  0
# 2   6            9        635          205                  0
# 3   7           13        644         1050                  0
# 4   9            8       1017         1489                  0

# %%
train.nunique()
# Out:
# id                   78369
# campaign_id             18
# coupon_id              866
# customer_id           1428
# redemption_status        2
# dtype: int64

# %%
campaign
# Out:
#     campaign_id campaign_type start_date   end_date
# 0            24             Y 2013-10-21 2013-12-20
# 1            25             Y 2013-10-21 2013-11-22
# 2            20             Y 2013-07-09 2013-11-16
# 3            23             Y 2013-08-10 2013-11-15
# 4            21             Y 2013-09-16 2013-10-18
# 5            22             X 2013-09-16 2013-10-18
# 6            18             X 2013-10-08 2013-04-10
# 7            19             Y 2013-08-26 2013-09-27
# 8            17             Y 2013-07-29 2013-08-30
# 9            16             Y 2013-07-15 2013-08-16
# 10           13             X 2013-05-19 2013-05-07
# 11           11             Y 2013-04-22 2013-07-06
# 12           12             Y 2013-04-22 2013-05-24
# 13           10             Y 2013-08-04 2013-10-05
# 14            9             Y 2013-11-03 2013-12-04
# 15            8             X 2013-02-16 2013-05-04
# 16            7             Y 2013-02-02 2013-08-03
# 17            6             Y 2013-01-28 2013-01-03
# 18            3             Y 2012-12-22 2013-02-16
# 19            5             Y 2013-12-01 2013-02-15
# 20            4             Y 2013-07-01 2013-08-02
# 21            1             Y 2012-12-12 2013-01-18
# 22            2             Y 2012-12-17 2013-01-18
# 23           30             X 2012-11-19 2013-04-01
# 24           29             Y 2012-08-10 2012-11-30
# 25           28             Y 2012-09-16 2012-11-16
# 26           27             Y 2012-08-25 2012-10-27
# 27           26             X 2012-12-08 2012-09-21

# %%
train.head()
# Out:
#    id  campaign_id  coupon_id  customer_id  redemption_status
# 0   1           13         27         1053                  0
# 1   2           13        116           48                  0
# 2   6            9        635          205                  0
# 3   7           13        644         1050                  0
# 4   9            8       1017         1489                  0

# %%
d1 = train.groupby('campaign_id').agg(redemption_frequency=('redemption_status','sum'))
d1
# Out:
#              redemption_frequency
# campaign_id
# 1                               1
# 2                               5
# 3                               2
# 4                               7
# 5                               7
# 6                               1
# 7                               4
# 8                             199
# 9                              23
# 10                              7
# 11                              6
# 12                             12
# 13                            346
# 26                             52
# 27                              1
# 28                              1
# 29                             16
# 30                             39

# %%
d2 = train['campaign_id'].value_counts().sort_index().rename('total_amount').to_frame()
d2.index.name = d1.index.name
d2
# Out:
#              total_amount
# campaign_id
# 1                     143
# 2                     768
# 3                     408
# 4                     972
# 5                    1827
# 6                      65
# 7                    1584
# 8                   22555
# 9                    3168
# 10                   1723
# 11                   2782
# 12                   2550
# 13                  22606
# 26                   6056
# 27                    324
# 28                    476
# 29                   3895
# 30                   6467

# %%
d2.iloc[:, 0].sum() == len(train)
# Out:
# True

# %%
coupon_types = train.coupon_id.nunique()
coupon_types
# Out:
# 866

# %%
d3 = train.groupby('campaign_id')['coupon_id'].nunique()
d3
# Out:
# campaign_id
# 1      11
# 2      16
# 3      34
# 4      12
# 5      11
# 6       1
# 7       8
# 8     208
# 9      18
# 10     14
# 11     13
# 12     15
# 13    207
# 26    181
# 27     27
# 28     28
# 29     33
# 30    178
# Name: coupon_id, dtype: int64

# %%
d3 = (d3 / coupon_types * 100).rename('coupon_covering_ratio%')
d3
# Out:
# campaign_id
# 1      1.270208
# 2      1.847575
# 3      3.926097
# 4      1.385681
# 5      1.270208
# 6      0.115473
# 7      0.923788
# 8     24.018476
# 9      2.078522
# 10     1.616628
# 11     1.501155
# 12     1.732102
# 13    23.903002
# 26    20.900693
# 27     3.117783
# 28     3.233256
# 29     3.810624
# 30    20.554273
# Name: coupon_covering_ratio%, dtype: float64

# %%
d4 = train.groupby('campaign_id')['customer_id'].nunique()
d4
# Out:
# campaign_id
# 1       13
# 2       48
# 3       12
# 4       81
# 5      166
# 6       65
# 7      198
# 8     1076
# 9      176
# 10     123
# 11     214
# 12     170
# 13    1077
# 26     332
# 27      12
# 28      17
# 29     118
# 30     361
# Name: customer_id, dtype: int64

# %%
n_customers = train.customer_id.nunique()
n_customers
# Out:
# 1428

# %%
d4 = train.groupby('campaign_id')['customer_id'].nunique()
d4
# Out:
# campaign_id
# 1       13
# 2       48
# 3       12
# 4       81
# 5      166
# 6       65
# 7      198
# 8     1076
# 9      176
# 10     123
# 11     214
# 12     170
# 13    1077
# 26     332
# 27      12
# 28      17
# 29     118
# 30     361
# Name: customer_id, dtype: int64

# %%
d4 = (d4 / n_customers * 100).rename('customer_covering_ratio%')
d4
# Out:
# campaign_id
# 1      0.910364
# 2      3.361345
# 3      0.840336
# 4      5.672269
# 5     11.624650
# 6      4.551821
# 7     13.865546
# 8     75.350140
# 9     12.324930
# 10     8.613445
# 11    14.985994
# 12    11.904762
# 13    75.420168
# 26    23.249300
# 27     0.840336
# 28     1.190476
# 29     8.263305
# 30    25.280112
# Name: customer_covering_ratio%, dtype: float64

# %%
d = pd.concat([d1, d2, d3, d4], axis=1)
d['redemption_ratio%'] = d['redemption_frequency'] / d['total_amount'] * 100
d = d.drop(columns=['redemption_frequency'])

# %%
campaign_origin = campaign.copy()
campaign_origin
# Out:
#     campaign_id campaign_type start_date   end_date
# 0            24             Y 2013-10-21 2013-12-20
# 1            25             Y 2013-10-21 2013-11-22
# 2            20             Y 2013-07-09 2013-11-16
# 3            23             Y 2013-08-10 2013-11-15
# 4            21             Y 2013-09-16 2013-10-18
# 5            22             X 2013-09-16 2013-10-18
# 6            18             X 2013-10-08 2013-04-10
# 7            19             Y 2013-08-26 2013-09-27
# 8            17             Y 2013-07-29 2013-08-30
# 9            16             Y 2013-07-15 2013-08-16
# 10           13             X 2013-05-19 2013-05-07
# 11           11             Y 2013-04-22 2013-07-06
# 12           12             Y 2013-04-22 2013-05-24
# 13           10             Y 2013-08-04 2013-10-05
# 14            9             Y 2013-11-03 2013-12-04
# 15            8             X 2013-02-16 2013-05-04
# 16            7             Y 2013-02-02 2013-08-03
# 17            6             Y 2013-01-28 2013-01-03
# 18            3             Y 2012-12-22 2013-02-16
# 19            5             Y 2013-12-01 2013-02-15
# 20            4             Y 2013-07-01 2013-08-02
# 21            1             Y 2012-12-12 2013-01-18
# 22            2             Y 2012-12-17 2013-01-18
# 23           30             X 2012-11-19 2013-04-01
# 24           29             Y 2012-08-10 2012-11-30
# 25           28             Y 2012-09-16 2012-11-16
# 26           27             Y 2012-08-25 2012-10-27
# 27           26             X 2012-12-08 2012-09-21

# %%
campaign = campaign_origin.copy()

# %%
for index, row in campaign.iterrows():
  if row.end_date < row.start_date:
    campaign.iloc[index, 2] = row.end_date
    campaign.iloc[index, 3] = row.start_date

campaign
# Out:
#     campaign_id campaign_type start_date   end_date
# 0            24             Y 2013-10-21 2013-12-20
# 1            25             Y 2013-10-21 2013-11-22
# 2            20             Y 2013-07-09 2013-11-16
# 3            23             Y 2013-08-10 2013-11-15
# 4            21             Y 2013-09-16 2013-10-18
# 5            22             X 2013-09-16 2013-10-18
# 6            18             X 2013-04-10 2013-10-08
# 7            19             Y 2013-08-26 2013-09-27
# 8            17             Y 2013-07-29 2013-08-30
# 9            16             Y 2013-07-15 2013-08-16
# 10           13             X 2013-05-07 2013-05-19
# 11           11             Y 2013-04-22 2013-07-06
# 12           12             Y 2013-04-22 2013-05-24
# 13           10             Y 2013-08-04 2013-10-05
# 14            9             Y 2013-11-03 2013-12-04
# 15            8             X 2013-02-16 2013-05-04
# 16            7             Y 2013-02-02 2013-08-03
# 17            6             Y 2013-01-03 2013-01-28
# 18            3             Y 2012-12-22 2013-02-16
# 19            5             Y 2013-02-15 2013-12-01
# 20            4             Y 2013-07-01 2013-08-02
# 21            1             Y 2012-12-12 2013-01-18
# 22            2             Y 2012-12-17 2013-01-18
# 23           30             X 2012-11-19 2013-04-01
# 24           29             Y 2012-08-10 2012-11-30
# 25           28             Y 2012-09-16 2012-11-16
# 26           27             Y 2012-08-25 2012-10-27
# 27           26             X 2012-09-21 2012-12-08

# %%
campaign['duration_days'] = (campaign['end_date'] - campaign['start_date']).dt.days

campaign['start_year'] = campaign['start_date'].dt.year
campaign['start_quarter'] = campaign.start_date.dt.quarter
campaign['start_week'] = campaign.start_date.dt.isocalendar().week
campaign['start_weekday'] = campaign.start_date.dt.weekday

campaign['end_year'] = campaign['end_date'].dt.year
campaign['end_quarter'] =  campaign.end_date.dt.quarter
campaign['end_week'] =  campaign.end_date.dt.isocalendar().week
campaign['end_weekday'] =  campaign.end_date.dt.weekday

# %%
df = campaign.drop(columns=['start_date', 'end_date'])

# %%
df
# Out:
#     campaign_id campaign_type  duration_days  start_year  start_quarter  \
# 0            24             Y             60        2013              4
# 1            25             Y             32        2013              4
# 2            20             Y            130        2013              3
# 3            23             Y             97        2013              3
# 4            21             Y             32        2013              3
# 5            22             X             32        2013              3
# 6            18             X            181        2013              2
# 7            19             Y             32        2013              3
# 8            17             Y             32        2013              3
# 9            16             Y             32        2013              3
# 10           13             X             12        2013              2
# 11           11             Y             75        2013              2
# 12           12             Y             32        2013              2
# 13           10             Y             62        2013              3
# 14            9             Y             31        2013              4
# 15            8             X             77        2013              1
# 16            7             Y            182        2013              1
# 17            6             Y             25        2013              1
# 18            3             Y             56        2012              4
# 19            5             Y            289        2013              1
# 20            4             Y             32        2013              3
# 21            1             Y             37        2012              4
# 22            2             Y             32        2012              4
# 23           30             X            133        2012              4
# 24           29             Y            112        2012              3
# 25           28             Y             61        2012              3
# 26           27             Y             63        2012              3
# 27           26             X             78        2012              3
#
#     start_week  start_weekday  end_year  end_quarter  end_week  end_weekday
# 0           43              0      2013            4        51            4
# 1           43              0      2013            4        47            4
# 2           28              1      2013            4        46            5
# 3           32              5      2013            4        46            4
# 4           38              0      2013            4        42            4
# 5           38              0      2013            4        42            4
# 6           15              2      2013            4        41            1
# 7           35              0      2013            3        39            4
# 8           31              0      2013            3        35            4
# 9           29              0      2013            3        33            4
# 10          19              1      2013            2        20            6
# 11          17              0      2013            3        27            5
# 12          17              0      2013            2        21            4
# 13          31              6      2013            4        40            5
# 14          44              6      2013            4        49            2
# 15           7              5      2013            2        18            5
# 16           5              5      2013            3        31            5
# 17           1              3      2013            1         5            0
# 18          51              5      2013            1         7            5
# 19           7              4      2013            4        48            6
# 20          27              0      2013            3        31            4
# 21          50              2      2013            1         3            4
# 22          51              0      2013            1         3            4
# 23          47              0      2013            2        14            0
# 24          32              4      2012            4        48            4
# 25          37              6      2012            4        46            4
# 26          34              5      2012            4        43            5
# 27          38              4      2012            4        49            5

# %%
# for col in ['end_year', 'start_year', 'campaign_type']:
#   dummy = pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=False)
#   df = pd.concat([dummy, df.drop(columns=col)], axis=1)

# %%
df = df.merge(d, on='campaign_id', how='right')

# %%
df['amount/day'] = df['total_amount'] / df['duration_days']

# %%
df["redemption_ratio"] = df['redemption_ratio%']
df = df.drop(columns = ['redemption_ratio%'])
df.rename(columns={"redemption_ratio":'redemption_ratio%'}, inplace=True)
df.to_markdown()
# Out:
# '|    |   campaign_id | campaign_type   |   duration_days |   start_year |   start_quarter |   start_week |   start_weekday |   end_year |   end_quarter |   end_week |   end_weekday |   total_amount |   coupon_covering_ratio% |   customer_covering_ratio% |   amount/day |   redemption_ratio% |\n|---:|--------------:|:----------------|----------------:|-------------:|----------------:|-------------:|----------------:|-----------:|--------------:|-----------:|--------------:|---------------:|-------------------------:|---------------------------:|-------------:|--------------------:|\n|  0 |             1 | Y               |              37 |         2012 |               4 |           50 |               2 |       2013 |             1 |          3 |             4 |            143 |                 1.27021  |                   0.910364 |      3.86486 |            0.699301 |\n|  1 |             2 | Y               |              32 |         2012 |               4 |           51 |               0 |       2013 |             1 |          3 |             4 |            768 |                 1.84758  |                   3.36134  |     24       |            0.651042 |\n|  2 |             3 | Y               |              56 |         2012 |               4 |           51 |               5 |       2013 |             1 |          7 |             5 |            408 |                 3.9261   |                   0.840336 |      7.28571 |            0.490196 |\n|  3 |             4 | Y               |              32 |         2013 |               3 |           27 |               0 |       2013 |             3 |         31 |             4 |            972 |                 1.38568  |                   5.67227  |     30.375   |            0.720165 |\n|  4 |             5 | Y               |             289 |         2013 |               1 |            7 |               4 |       2013 |             4 |         48 |             6 |           1827 |                 1.27021  |                  11.6246   |      6.3218  |            0.383142 |\n|  5 |             6 | Y               |              25 |         2013 |               1 |            1 |               3 |       2013 |             1 |          5 |             0 |             65 |                 0.115473 |                   4.55182  |      2.6     |            1.53846  |\n|  6 |             7 | Y               |             182 |         2013 |               1 |            5 |               5 |       2013 |             3 |         31 |             5 |           1584 |                 0.923788 |                  13.8655   |      8.7033  |            0.252525 |\n|  7 |             8 | X               |              77 |         2013 |               1 |            7 |               5 |       2013 |             2 |         18 |             5 |          22555 |                24.0185   |                  75.3501   |    292.922   |            0.882288 |\n|  8 |             9 | Y               |              31 |         2013 |               4 |           44 |               6 |       2013 |             4 |         49 |             2 |           3168 |                 2.07852  |                  12.3249   |    102.194   |            0.72601  |\n|  9 |            10 | Y               |              62 |         2013 |               3 |           31 |               6 |       2013 |             4 |         40 |             5 |           1723 |                 1.61663  |                   8.61345  |     27.7903  |            0.406268 |\n| 10 |            11 | Y               |              75 |         2013 |               2 |           17 |               0 |       2013 |             3 |         27 |             5 |           2782 |                 1.50115  |                  14.986    |     37.0933  |            0.215672 |\n| 11 |            12 | Y               |              32 |         2013 |               2 |           17 |               0 |       2013 |             2 |         21 |            ...

# %%
df.to_csv('/content/drive/MyDrive/Project Data Mining/regression_campaign.csv')
